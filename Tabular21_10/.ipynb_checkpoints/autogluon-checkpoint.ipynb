# %%
import os
os.environ["CUDA_DEVICE_ORDER"] = "PCI_BUS_ID"
os.environ["CUDA_VISIBLE_DEVICES"] = "3"
os.environ["KAGGLE_USERNAME"] = 'hyunw3'
os.environ["KAGGLE_KEY"] = "b48a329f42b53a6bda2afd4cf341bcf2"
# https://auto.gluon.ai/stable/tutorials/tabular_prediction/tabular-quickstart.html
import tensorflow as tf
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
import torch

# %%
from autogluon.tabular import TabularDataset, TabularPredictor

# %%
train_data = TabularDataset("./train.csv")
subsample_size = 500
train_data.sample(n=subsample_size, random_state=0)
# Out:
#             id        f0        f1        f2        f3        f4        f5  \
# 157105  157105  0.225628  0.369954  0.086533  0.220996  0.413357  0.406488
# 374554  374554  0.156088  0.479218  0.087969  0.335879  0.601985  0.492081
# 688694  688694  0.246660  0.465889  0.022856  0.310019  0.562853  0.512969
# 265381  265381  0.253541  0.495103  0.236774  0.215441  0.540664  0.422883
# 955415  955415  0.289054  0.378237  0.006109  0.272483  0.748737  0.515908
# ...        ...       ...       ...       ...       ...       ...       ...
# 26972    26972  0.245825  0.396460  0.245351  0.232621  0.776057  0.334820
# 460196  460196  0.161303  0.454262  0.014427  0.260020  0.589798  0.373510
# 907019  907019  0.229526  0.571115  0.173815  0.508466  0.489185  0.386501
# 229397  229397  0.181321  0.389418  0.096659  0.230548  0.606180  0.460271
# 25732    25732  0.181674  0.584593  0.174506  0.250096  0.689036  0.464393
#
#               f6        f7        f8  ...  f276  f277  f278  f279  f280  f281  \
# 157105  0.502186  0.535051  0.398884  ...     1     0     0     0     0     0
# 374554  0.361206  0.726592  0.691247  ...     0     1     1     0     0     0
# 688694  0.393365  0.600628  0.523308  ...     0     0     0     0     0     0
# 265381  0.409836  0.808747  0.353328  ...     0     0     0     1     1     0
# 955415  0.362741  0.629370  0.444692  ...     0     0     0     0     0     0
# ...          ...       ...       ...  ...   ...   ...   ...   ...   ...   ...
# 26972   0.817839  0.652080  0.622675  ...     0     0     0     0     1     0
# 460196  0.475360  0.613104  0.344057  ...     0     0     0     0     0     1
# 907019  0.465174  0.630219  0.391914  ...     0     0     0     0     0     0
# 229397  0.389354  0.731110  0.617478  ...     0     0     0     0     0     0
# 25732   0.095494  0.653945  0.304280  ...     1     0     0     0     0     0
#
#         f282  f283  f284  target
# 157105     1     0     0       1
# 374554     0     0     0       0
# 688694     0     0     0       0
# 265381     0     0     0       0
# 955415     0     0     0       1
# ...      ...   ...   ...     ...
# 26972      0     0     0       1
# 460196     0     1     1       0
# 907019     0     0     0       0
# 229397     0     0     1       0
# 25732      0     0     0       1
#
# [500 rows x 287 columns]

# %%
test_data = TabularDataset("./test.csv")
subsample_size = 500
test_data.sample(n=subsample_size, random_state=0)
# Out:
#              id        f0        f1        f2        f3        f4        f5  \
# 194257  1194257  0.177652  0.402826  0.170229  0.279291  0.449732  0.349957
# 396319  1396319  0.326258  0.421919  0.162970  0.233764  0.669121  0.363471
# 138738  1138738  0.207297  0.469348  0.164248  0.335177  0.483002  0.443952
# 66570   1066570  0.203267  0.562071  0.367516  0.219651  0.656695  0.409316
# 149424  1149424  0.227488  0.604065  0.090917  0.320712  0.577093  0.367012
# ...         ...       ...       ...       ...       ...       ...       ...
# 176678  1176678  0.163133  0.388365  0.007658  0.348349  0.629932  0.330511
# 448334  1448334  0.161898  0.353998  0.017979  0.245647  0.507021  0.454971
# 458895  1458895  0.230312  0.390605  0.098201  0.210367  0.582872  0.387836
# 351025  1351025  0.203836  0.616144  0.019308  0.272592  0.609978  0.433441
# 360979  1360979  0.179337  0.509545  0.021586  0.208298  0.596239  0.510835
#
#               f6        f7        f8  ...  f275  f276  f277  f278  f279  f280  \
# 194257  0.450216  0.676548  0.431982  ...     1     1     0     0     0     0
# 396319  0.422830  0.663648  0.598159  ...     0     0     0     1     0     0
# 138738  0.358411  0.676115  0.550601  ...     0     0     0     0     0     0
# 66570   0.476351  0.657574  0.371572  ...     0     0     0     0     0     1
# 149424  0.455212  0.737396  0.531693  ...     0     1     0     0     0     0
# ...          ...       ...       ...  ...   ...   ...   ...   ...   ...   ...
# 176678  0.174350  0.609330  0.555974  ...     0     0     0     0     0     0
# 448334  0.506786  0.709880  0.635846  ...     0     0     1     0     1     0
# 458895  0.480212  0.589985  0.335449  ...     1     0     0     1     0     0
# 351025  0.245892  0.662670  0.299882  ...     1     0     0     0     1     0
# 360979  0.502423  0.599243  0.349234  ...     1     0     0     0     0     0
#
#         f281  f282  f283  f284
# 194257     1     0     1     0
# 396319     1     0     0     0
# 138738     0     0     0     0
# 66570      1     0     1     0
# 149424     0     0     0     0
# ...      ...   ...   ...   ...
# 176678     0     0     0     0
# 448334     0     1     0     0
# 458895     0     1     0     0
# 351025     0     0     0     0
# 360979     0     0     0     0
#
# [500 rows x 286 columns]

# %%
label='target'
print("summary of class variable : \n",train_data[label].describe())
# Out:
# summary of class variable :
#  count    1000000.000000
# mean           0.500485
# std            0.500000
# min            0.000000
# 25%            0.000000
# 50%            1.000000
# 75%            1.000000
# max            1.000000
# Name: target, dtype: float64

# %%
model_savepath = "./models/"
#if os.path.exists(model_savepath) is False:
#    os.mkdir(model_savepath)

# %%
predictor = TabularPredictor(label=label, path=model_savepath).fit(train_data)
# Out:
# Warning: path already exists! This predictor may overwrite an existing predictor! path="./models/"
# Warning: Training may take a very long time because `time_limit` was not specified and `train_data` is large (1000000 samples, 2296.0 MB).
# 	Consider setting `time_limit` to ensure training finishes within an expected duration or experiment with a small portion of `train_data` to identify an ideal `presets` and `hyperparameters` configuration.
# Beginning AutoGluon training ...
# AutoGluon will save models to "./models/"
# AutoGluon Version:  0.3.2b20211005
# Train Data Rows:    1000000
# Train Data Columns: 286
# Preprocessing data ...
# AutoGluon infers your prediction problem is: 'binary' (because only two unique label-values observed).
# 	2 unique label values:  [1, 0]
# 	If 'binary' is not the correct problem_type, please manually specify the problem_type argument in fit() (You may specify problem_type as one of: ['binary', 'multiclass', 'regression'])
# Selected class <--> label mapping:  class 1 = 1, class 0 = 0
# Using Feature Generators to preprocess the data ...
# Fitting AutoMLPipelineFeatureGenerator...
# 	Available Memory:                    521636.4 MB
# 	Train Data (Original)  Memory Usage: 2288.0 MB (0.4% of available memory)
# 	Inferring data type of each feature based on column values. Set feature_metadata_in to manually specify special dtypes of the features.
# 	Stage 1 Generators:
# 		Fitting AsTypeFeatureGenerator...
# 			Note: Converting 45 features to boolean dtype as they only contain 2 unique values.
# 	Stage 2 Generators:
# 		Fitting FillNaFeatureGenerator...
# 	Stage 3 Generators:
# 		Fitting IdentityFeatureGenerator...
# 	Stage 4 Generators:
# 		Fitting DropUniqueFeatureGenerator...
# 	Types of features in original data (raw dtype, special dtypes):
# 		('float', []) : 240 | ['f0', 'f1', 'f2', 'f3', 'f4', ...]
# 		('int', [])   :  46 | ['id', 'f22', 'f43', 'f242', 'f243', ...]
# 	Types of features in processed data (raw dtype, special dtypes):
# 		('float', [])     : 240 | ['f0', 'f1', 'f2', 'f3', 'f4', ...]
# 		('int', [])       :   1 | ['id']
# 		('int', ['bool']) :  45 | ['f22', 'f43', 'f242', 'f243', 'f244', ...]
# 	39.9s = Fit runtime
# 	286 features in original data used to generate 286 features in processed data.
# 	Train Data (Processed) Memory Usage: 1973.0 MB (0.4% of available memory)
# Data preprocessing and feature engineering runtime = 43.71s ...
# AutoGluon will gauge predictive performance using evaluation metric: 'accuracy'
# 	To change this, specify the eval_metric argument of fit()
# Automatically generating train/validation split with holdout_frac=0.01, Train Rows: 990000, Val Rows: 10000
# Fitting 13 L1 models ...
# Fitting model: KNeighborsUnif ...
# 	0.5038	 = Validation score   (accuracy)
# 	100.38s	 = Training   runtime
# 	0.48s	 = Validation runtime
# Fitting model: KNeighborsDist ...
# 	0.5039	 = Validation score   (accuracy)
# 	101.13s	 = Training   runtime
# 	0.51s	 = Validation runtime
# Fitting model: LightGBMXT ...
# 	0.7548	 = Validation score   (accuracy)
# 	27.61s	 = Training   runtime
# 	0.07s	 = Validation runtime
# Fitting model: LightGBM ...
# 	0.7554	 = Validation score   (accuracy)
# 	23.06s	 = Training   runtime
# 	0.05s	 = Validation runtime
# Fitting model: RandomForestGini ...
# 	0.7597	 = Validation score   (accuracy)
# 	478.6s	 = Training   runtime
# 	0.6s	 = Validation runtime
# Fitting model: RandomForestEntr ...
# 	0.76	 = Validation score   (accuracy)
# 	643.97s	 = Training   runtime
# 	0.37s	 = Validation runtime
# Fitting model: CatBoost ...
# 	0.7571	 = Validation score   (accuracy)
# 	17.2s	 = Training   runtime
# 	0.03s	 = Validation runtime
# Fitting model: ExtraTreesGini ...
# 	0.7543	 = Validation score   (accuracy)
# 	235.03s	 = Training   runtime
# 	0.47s	 = Validation runtime
# Fitting model: ExtraTreesEntr ...
# 	0.7543	 = Validation score   (accuracy)
# 	227.85s	 = Training   runtime
# 	0.36s	 = Validation runtime
# Fitting model: NeuralNetFastAI ...
# 	0.7665	 = Validation score   (accuracy)
# 	1422.09s	 = Training   runtime
# 	0.33s	 = Validation runtime
# Fitting model: XGBoost ...
# 	0.7563	 = Validation score   (accuracy)
# 	46.01s	 = Training   runtime
# 	0.18s	 = Validation runtime
# Fitting model: NeuralNetMXNet ...
# 	Warning: Exception caused NeuralNetMXNet to fail during training (ImportError)... Skipping this model.
# 		Unable to import dependency mxnet. A quick tip is to install via `pip install mxnet --upgrade`, or `pip install mxnet_cu101 --upgrade`
# Fitting model: LightGBMLarge ...
# 	0.7582	 = Validation score   (accuracy)
# 	38.1s	 = Training   runtime
# 	0.09s	 = Validation runtime
# Fitting model: WeightedEnsemble_L2 ...
# 	0.7679	 = Validation score   (accuracy)
# 	3.69s	 = Training   runtime
# 	0.01s	 = Validation runtime
# AutoGluon training complete, total runtime = 3568.49s ...
# TabularPredictor saved. To load, use: predictor = TabularPredictor.load("./models/")

# %%
y_pred = predictor.predict(test_data)
y_pred
# Out:
# 0         1
# 1         0
# 2         1
# 3         1
# 4         0
#          ..
# 499995    1
# 499996    1
# 499997    0
# 499998    1
# 499999    0
# Name: target, Length: 500000, dtype: int64

# %%
test_id = test_data['id']
test_pred = pd.DataFrame(y_pred)
test_pred#.head()
# Out:
#         target
# 0            1
# 1            0
# 2            1
# 3            1
# 4            0
# ...        ...
# 499995       1
# 499996       1
# 499997       0
# 499998       1
# 499999       0
#
# [500000 rows x 1 columns]

# %%
d_frame = pd.DataFrame()
d_frame["id"] = test_id
d_frame["target"] = y_pred
d_frame.to_csv("./submit_1005.csv",index=False)

# %%
d_frame
# Out:
#              id  target
# 0       1000000       1
# 1       1000001       0
# 2       1000002       1
# 3       1000003       1
# 4       1000004       0
# ...         ...     ...
# 499995  1499995       1
# 499996  1499996       1
# 499997  1499997       0
# 499998  1499998       1
# 499999  1499999       0
#
# [500000 rows x 2 columns]

# %%
d_frame.drop([""])
# Out:
# ------------------------------------------------------------------
# KeyError                         Traceback (most recent call last)
# <ipython-input-24-d2ec6898df6e> in <module>
# ----> 1 d_frame.drop([""])
#
# /media/2/hwbae0326/anaconda3/envs/local_pytorch/lib/python3.7/site-packages/pandas/core/frame.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    4313             level=level,
#    4314             inplace=inplace,
# -> 4315             errors=errors,
#    4316         )
#    4317
#
# /media/2/hwbae0326/anaconda3/envs/local_pytorch/lib/python3.7/site-packages/pandas/core/generic.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    4151         for axis, labels in axes.items():
#    4152             if labels is not None:
# -> 4153                 obj = obj._drop_axis(labels, axis, level=level, errors=errors)
#    4154
#    4155         if inplace:
#
# /media/2/hwbae0326/anaconda3/envs/local_pytorch/lib/python3.7/site-packages/pandas/core/generic.py in _drop_axis(self, labels, axis, level, errors)
#    4186                 new_axis = axis.drop(labels, level=level, errors=errors)
#    4187             else:
# -> 4188                 new_axis = axis.drop(labels, errors=errors)
#    4189             result = self.reindex(**{axis_name: new_axis})
#    4190
#
# /media/2/hwbae0326/anaconda3/envs/local_pytorch/lib/python3.7/site-packages/pandas/core/indexes/base.py in drop(self, labels, errors)
#    5589         if mask.any():
#    5590             if errors != "ignore":
# -> 5591                 raise KeyError(f"{labels[mask]} not found in axis")
#    5592             indexer = indexer[~mask]
#    5593         return self.delete(indexer)
#
# KeyError: "[''] not found in axis"

# %%
predictor.leaderboard(train_data, silent=True)
# Out:
#                   model  score_test  score_val  pred_time_test  pred_time_val  \
# 0      RandomForestEntr    0.997600     0.7600       27.384627       0.371036
# 1      RandomForestGini    0.997597     0.7597       31.012798       0.595551
# 2        ExtraTreesEntr    0.997543     0.7543       32.678461       0.358881
# 3        ExtraTreesGini    0.997543     0.7543       34.464632       0.470721
# 4        KNeighborsDist    0.995039     0.5039       47.364411       0.507076
# 5   WeightedEnsemble_L2    0.803928     0.7679       89.185238       1.105203
# 6       NeuralNetFastAI    0.769960     0.7665       37.318365       0.334738
# 7         LightGBMLarge    0.758485     0.7582        2.057775       0.087481
# 8               XGBoost    0.757800     0.7563       17.323693       0.181452
# 9              CatBoost    0.757373     0.7571        0.119640       0.034171
# 10             LightGBM    0.756749     0.7554        2.840072       0.046370
# 11           LightGBMXT    0.755925     0.7548        2.212051       0.069854
# 12       KNeighborsUnif    0.685729     0.5038       31.184058       0.479516
#
#        fit_time  pred_time_test_marginal  pred_time_val_marginal  \
# 0    643.974980                27.384627                0.371036
# 1    478.600332                31.012798                0.595551
# 2    227.848197                32.678461                0.358881
# 3    235.033646                34.464632                0.470721
# 4    101.133215                47.364411                0.507076
# 5   2204.551776                 0.048655                0.014271
# 6   1422.094573                37.318365                0.334738
# 7     38.097066                 2.057775                0.087481
# 8     46.013745                17.323693                0.181452
# 9     17.199483                 0.119640                0.034171
# 10    23.063179                 2.840072                0.046370
# 11    27.613937                 2.212051                0.069854
# 12   100.384556                31.184058                0.479516
#
#     fit_time_marginal  stack_level  can_infer  fit_order
# 0          643.974980            1       True          6
# 1          478.600332            1       True          5
# 2          227.848197            1       True          9
# 3          235.033646            1       True          8
# 4          101.133215            1       True          2
# 5            3.694295            2       True         13
# 6         1422.094573            1       True         10
# 7           38.097066            1       True         12
# 8           46.013745            1       True         11
# 9           17.199483            1       True          7
# 10          23.063179            1       True          4
# 11          27.613937            1       True          3
# 12         100.384556            1       True          1

# %%
results = predictor.fit_summary(show_plot=True)
results
# Out:
# *** Summary of fit() ***
# Estimated performance of each model:
#                   model  score_val  pred_time_val     fit_time  pred_time_val_marginal  fit_time_marginal  stack_level  can_infer  fit_order
# 0   WeightedEnsemble_L2     0.7679       1.105203  2204.551776                0.014271           3.694295            2       True         13
# 1       NeuralNetFastAI     0.7665       0.334738  1422.094573                0.334738        1422.094573            1       True         10
# 2      RandomForestEntr     0.7600       0.371036   643.974980                0.371036         643.974980            1       True          6
# 3      RandomForestGini     0.7597       0.595551   478.600332                0.595551         478.600332            1       True          5
# 4         LightGBMLarge     0.7582       0.087481    38.097066                0.087481          38.097066            1       True         12
# 5              CatBoost     0.7571       0.034171    17.199483                0.034171          17.199483            1       True          7
# 6               XGBoost     0.7563       0.181452    46.013745                0.181452          46.013745            1       True         11
# 7              LightGBM     0.7554       0.046370    23.063179                0.046370          23.063179            1       True          4
# 8            LightGBMXT     0.7548       0.069854    27.613937                0.069854          27.613937            1       True          3
# 9        ExtraTreesEntr     0.7543       0.358881   227.848197                0.358881         227.848197            1       True          9
# 10       ExtraTreesGini     0.7543       0.470721   235.033646                0.470721         235.033646            1       True          8
# 11       KNeighborsDist     0.5039       0.507076   101.133215                0.507076         101.133215            1       True          2
# 12       KNeighborsUnif     0.5038       0.479516   100.384556                0.479516         100.384556            1       True          1
# Number of models trained: 13
# Types of models trained:
# {'LGBModel', 'NNFastAiTabularModel', 'CatBoostModel', 'XGBoostModel', 'XTModel', 'KNNModel', 'WeightedEnsembleModel', 'RFModel'}
# Bagging used: False
# Multi-layer stack-ensembling used: False
# Feature Metadata (Processed):
# (raw dtype, special dtypes):
# ('float', [])     : 240 | ['f0', 'f1', 'f2', 'f3', 'f4', ...]
# ('int', [])       :   1 | ['id']
# ('int', ['bool']) :  45 | ['f22', 'f43', 'f242', 'f243', 'f244', ...]
# *** End of fit() summary ***
# /media/2/hwbae0326/package/autogluon/core/src/autogluon/core/utils/plots.py:138: UserWarning: AutoGluon summary plots cannot be created because bokeh is not installed. To see plots, please do: "pip install bokeh==2.0.1"
#   warnings.warn('AutoGluon summary plots cannot be created because bokeh is not installed. To see plots, please do: "pip install bokeh==2.0.1"')
# {'model_types': {'KNeighborsUnif': 'KNNModel',
#   'KNeighborsDist': 'KNNModel',
#   'LightGBMXT': 'LGBModel',
#   'LightGBM': 'LGBModel',
#   'RandomForestGini': 'RFModel',
#   'RandomForestEntr': 'RFModel',
#   'CatBoost': 'CatBoostModel',
#   'ExtraTreesGini': 'XTModel',
#   'ExtraTreesEntr': 'XTModel',
#   'NeuralNetFastAI': 'NNFastAiTabularModel',
#   'XGBoost': 'XGBoostModel',
#   'LightGBMLarge': 'LGBModel',
#   'WeightedEnsemble_L2': 'WeightedEnsembleModel'},
#  'model_performance': {'KNeighborsUnif': 0.5038,
#   'KNeighborsDist': 0.5039,
#   'LightGBMXT': 0.7548,
#   'LightGBM': 0.7554,
#   'RandomForestGini': 0.7597,
#   'RandomForestEntr': 0.76,
#   'CatBoost': 0.7571,
#   'ExtraTreesGini': 0.7543,
#   'ExtraTreesEntr': 0.7543,
#   'NeuralNetFastAI': 0.7665,
#   'XGBoost': 0.7563,
#   'LightGBMLarge': 0.7582,
#   'WeightedEnsemble_L2': 0.7679},
#  'model_best': 'WeightedEnsemble_L2',
#  'model_paths': {'KNeighborsUnif': './models/models/KNeighborsUnif/',
#   'KNeighborsDist': './models/models/KNeighborsDist/',
#   'LightGBMXT': './models/models/LightGBMXT/',
#   'LightGBM': './models/models/LightGBM/',
#   'RandomForestGini': './models/models/RandomForestGini/',
#   'RandomForestEntr': './models/models/RandomForestEntr/',
#   'CatBoost': './models/models/CatBoost/',
#   'ExtraTreesGini': './models/models/ExtraTreesGini/',
#   'ExtraTreesEntr': './models/models/ExtraTreesEntr/',
#   'NeuralNetFastAI': './models/models/NeuralNetFastAI/',
#   'XGBoost': './models/models/XGBoost/',
#   'LightGBMLarge': './models/models/LightGBMLarge/',
#   'WeightedEnsemble_L2': './models/models/WeightedEnsemble_L2/'},
#  'model_fit_times': {'KNeighborsUnif': 100.38455581665039,
#   'KNeighborsDist': 101.13321471214294,
#   'LightGBMXT': 27.613937377929688,
#   'LightGBM': 23.06317949295044,
#   'RandomForestGini': 478.6003315448761,
#   'RandomForestEntr': 643.9749801158905,
#   'CatBoost': 17.199482679367065,
#   'ExtraTreesGini': 235.0336458683014,
#   'ExtraTreesEntr': 227.84819746017456,
#   'NeuralNetFastAI': 1422.0945732593536,
#   'XGBoost': 46.013744592666626,
#   'LightGBMLarge': 38.097065925598145,
#   'WeightedEnsemble_L2': 3.6942954063415527},
#  'model_pred_times': {'KNeighborsUnif': 0.47951555252075195,
#   'KNeighborsDist': 0.5070762634277344,
#   'LightGBMXT': 0.0698544979095459,
#   'LightGBM': 0.04636979103088379,
#   'RandomForestGini': 0.5955510139465332,
#   'RandomForestEntr': 0.3710362911224365,
#   'CatBoost': 0.034171342849731445,
#   'ExtraTreesGini': 0.4707212448120117,
#   'ExtraTreesEntr': 0.35888099670410156,
#   'NeuralNetFastAI': 0.33473753929138184,
#   'XGBoost': 0.18145203590393066,
#   'LightGBMLarge': 0.08748149871826172,
#   'WeightedEnsemble_L2': 0.014271259307861328},
#  'num_bag_folds': 0,
#  'max_stack_level': 2,
#  'num_classes': 2,
#  'model_hyperparams': {'KNeighborsUnif': {'weights': 'uniform', 'n_jobs': -1},
#   'KNeighborsDist': {'weights': 'distance', 'n_jobs': -1},
#   'LightGBMXT': {'num_boost_round': 10000,
#    'num_threads': -1,
#    'learning_rate': 0.05,
#    'objective': 'binary',
#    'verbose': -1,
#    'boosting_type': 'gbdt',
#    'two_round': True,
#    'extra_trees': True},
#   'LightGBM': {'num_boost_round': 10000,
#    'num_threads': -1,
#    'learning_rate': 0.05,
#    'objective': 'binary',
#    'verbose': -1,
#    'boosting_type': 'gbdt',
#    'two_round': True},
#   'RandomForestGini': {'n_estimators': 300,
#    'n_jobs': -1,
#    'random_state': 0,
#    'bootstrap': True,
#    'criterion': 'gini'},
#   'RandomForestEntr': {'n_estimators': 300,
#    'n_jobs': -1,
#    'random_state': 0,
#    'bootstrap': True,
#    'criterion': 'entropy'},
#   'CatBoost': {'iterations': 10000,
#    'learning_rate': 0.05,
#    'random_seed': 0,
#    'allow_writing_files': False,
#    'eval_metric': 'Accuracy'},
#   'ExtraTreesGini': {'n_estimators': 300,
#    'n_jobs': -1,
#    'random_state': 0,
#    'bootstrap': True,
#    'criterion': 'gini'},
#   'ExtraTreesEntr': {'n_estimators': 300,
#    'n_jobs': -1,
#    'random_state': 0,
#    'bootstrap': True,
#    'criterion': 'entropy'},
#   'NeuralNetFastAI': {'layers': None,
#    'emb_drop': 0.1,
#    'ps': 0.1,
#    'bs': 256,
#    'lr': 0.01,
#    'epochs': 30,
#    'early.stopping.min_delta': 0.0001,
#    'early.stopping.patience': 20,
#    'smoothing': 0.0},
#   'XGBoost': {'n_estimators': 10000,
#    'learning_rate': 0.1,
#    'n_jobs': -1,
#    'proc.max_category_levels': 100,
#    'objective': 'binary:logistic',
#    'booster': 'gbtree',
#    'use_label_encoder': False},
#   'LightGBMLarge': {'num_boost_round': 10000,
#    'num_threads': -1,
#    'learning_rate': 0.03,
#    'objective': 'binary',
#    'verbose': -1,
#    'boosting_type': 'gbdt',
#    'two_round': True,
#    'num_leaves': 128,
#    'feature_fraction': 0.9,
#    'min_data_in_leaf': 5},
#   'WeightedEnsemble_L2': {'use_orig_features': False,
#    'max_base_models': 25,
#    'max_base_models_per_type': 5,
#    'save_bag_folds': True}},
#  'leaderboard':                   model  score_val  pred_time_val     fit_time  \
#  0   WeightedEnsemble_L2     0.7679       1.105203  2204.551776
#  1       NeuralNetFastAI     0.7665       0.334738  1422.094573
#  2      RandomForestEntr     0.7600       0.371036   643.974980
#  3      RandomForestGini     0.7597       0.595551   478.600332
#  4         LightGBMLarge     0.7582       0.087481    38.097066
#  5              CatBoost     0.7571       0.034171    17.199483
#  6               XGBoost     0.7563       0.181452    46.013745
#  7              LightGBM     0.7554       0.046370    23.063179
#  8            LightGBMXT     0.7548       0.069854    27.613937
#  9        ExtraTreesEntr     0.7543       0.358881   227.848197
#  10       ExtraTreesGini     0.7543       0.470721   235.033646
#  11       KNeighborsDist     0.5039       0.507076   101.133215
#  12       KNeighborsUnif     0.5038       0.479516   100.384556
#
#      pred_time_val_marginal  fit_time_marginal  stack_level  can_infer  \
#  0                 0.014271           3.694295            2       True
#  1                 0.334738        1422.094573            1       True
#  2                 0.371036         643.974980            1       True
#  3                 0.595551         478.600332            1       True
#  4                 0.087481          38.097066            1       True
#  5                 0.034171          17.199483            1       True
#  6                 0.181452          46.013745            1       True
#  7                 0.046370          23.063179            1       True
#  8                 0.069854          27.613937            1       True
#  9                 0.358881         227.848197            1       True
#  10                0.470721         235.033646            1       True
#  11                0.507076         101.133215            1       True
#  12                0.479516         100.384556            1       True
#
#      fit_order
#  0          13
#  1          10
#  2           6
#  3           5
#  4          12
#  5           7
#  6          11
#  7           4
#  8           3
#  9           9
#  10          8
#  11          2
#  12          1  }
